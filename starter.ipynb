# %%
from statsbombpy import sb
import json
import pandas as pd

# %%
with open('/Users/annahartman/cs181yhmc/StatsBomb/data/events/7298.json') as f:
  data = json.load(f)

# print(data) # checking the data
# print(len(data)) # checking the length of the data

# converting json file into a pandas dataframe
df = pd.DataFrame([data[0]])
for x in range(1, len(data)):
    temp_df = pd.DataFrame([data[x]])
    # print(temp_df)
    df = pd.concat([df, temp_df])
    #df = pd.concat(temp_df,ignore_index = True)
df

# df = pd.DataFrame([data[0]])
# df2 = pd.DataFrame([data[1]])
# df = df.append(df2, ignore_index = True)
# df

#df = pd.read_json('/Users/rachelyang/Desktop/StatsBomb/open-data-master/data/events/7430.json', orient ='index')
# print(data.values())
# Out:
#                                       id  index  period     timestamp  minute  \
# 0   0b483cd2-1d36-49a0-85c2-149a9de553df      1       1  00:00:00.000       0
# 0   2c873afb-73bb-48a1-9fd5-bfe1400b4a83      2       1  00:00:00.000       0
# 0   040940a1-5972-431e-b6ac-e723edd8e7c2      3       1  00:00:00.000       0
# 0   5ba286bd-c397-4ac4-b12f-6bace943afce      4       1  00:00:00.000       0
# 0   2a456ec2-352c-499b-b5cc-e68bf84c7e9a      5       1  00:00:00.100       0
# ..                                   ...    ...     ...           ...     ...
# 0   49e5bbe8-de8b-4b45-a168-4e130960c371   3789       2  00:48:50.958      93
# 0   733c3090-32b6-4c6f-870e-80d288ba927f   3790       2  00:48:53.558      93
# 0   f5388757-108e-4280-95c1-e95aa4a8a281   3791       2  00:48:57.038      93
# 0   72cdfa47-772b-4487-bdea-12dcb36461a2   3792       2  00:49:04.531      94
# 0   1939c3fe-9e07-4698-8c09-f43715b7982b   3793       2  00:49:04.531      94
#
# ...

# %%
df_matches = sb.matches(competition_id=55, season_id=43)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   match_id               51 non-null     int64
#  1   match_date             51 non-null     object
#  2   kick_off               51 non-null     object
#  3   competition            51 non-null     object
#  4   season                 51 non-null     object
#  5   home_team              51 non-null     object
#  6   away_team              51 non-null     object
#  7   home_score             51 non-null     int64
#  8   away_score             51 non-null     int64
#  9   match_status           51 non-null     object
#  10  match_status_360       51 non-null     object
#  11  last_updated           51 non-null     object
#  12  last_updated_360       51 non-null     object
#  13  match_week             51 non-null     int64
# ...

# %%
df_matches = sb.matches(competition_id=55, season_id=43)

# %%
sb.matches(competition_id=55, season_id=43)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     match_id  match_date      kick_off         competition season  \
# 0    3788753  2021-06-16  15:00:00.000  Europe - UEFA Euro   2020
# 1    3788765  2021-06-20  18:00:00.000  Europe - UEFA Euro   2020
# 2    3795107  2021-07-02  21:00:00.000  Europe - UEFA Euro   2020
# 3    3795221  2021-07-07  21:00:00.000  Europe - UEFA Euro   2020
# 4    3795506  2021-07-11  21:00:00.000  Europe - UEFA Euro   2020
# 5    3794688  2021-06-29  18:00:00.000  Europe - UEFA Euro   2020
# 6    3794692  2021-06-29  21:00:00.000  Europe - UEFA Euro   2020
# 7    3794686  2021-06-28  18:00:00.000  Europe - UEFA Euro   2020
# 8    3794687  2021-06-27  21:00:00.000  Europe - UEFA Euro   2020
# ...

# %%
events = sb.events(match_id = 3788753)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
events
# Out:
#      50_50 ball_receipt_outcome ball_recovery_recovery_failure  \
# 0      NaN                  NaN                            NaN
# 1      NaN                  NaN                            NaN
# 2      NaN                  NaN                            NaN
# 3      NaN                  NaN                            NaN
# 4      NaN                  NaN                            NaN
# ...    ...                  ...                            ...
# 3801   NaN                  NaN                            NaN
# 3802   NaN                  NaN                            NaN
# 3803   NaN                  NaN                            NaN
# 3804   NaN                  NaN                            NaN
# 3805   NaN                  NaN                            NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  \
# 0                   NaN                  NaN                 NaN
# 1                   NaN                  NaN                 NaN
# ...

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3806 entries, 0 to 3805
# Data columns (total 86 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   50_50                           2 non-null      object
#  1   ball_receipt_outcome            146 non-null    object
#  2   ball_recovery_recovery_failure  5 non-null      object
#  3   carry_end_location              841 non-null    object
#  4   clearance_aerial_won            20 non-null     object
#  5   clearance_body_part             67 non-null     object
#  6   clearance_head                  35 non-null     object
#  7   clearance_left_foot             15 non-null     object
#  8   clearance_other                 2 non-null      object
#  9   clearance_right_foot            15 non-null     object
#  10  counterpress                    107 non-null    object
#  11  dribble_nutmeg                  1 non-null      object
# ...

# %%
events.loc[events['play_pattern'] == 'From Throw In']
# Out:
#                                                   50_50 ball_receipt_outcome  \
# 34                                                  NaN                  NaN
# 35                                                  NaN                  NaN
# 36                                                  NaN                  NaN
# 106                                                 NaN                  NaN
# 107                                                 NaN                  NaN
# ...                                                 ...                  ...
# 3791             {'outcome': {'id': 1, 'name': 'Lost'}}                  NaN
# 3792  {'outcome': {'id': 2, 'name': 'Success To Oppo...                  NaN
# 3795                                                NaN                  NaN
# 3796                                                NaN                  NaN
# 3797                                                NaN                  NaN
#
# ...
