# %%
# import libraries
from statsbombpy import sb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import statsmodels.api as sm

# %%
# obtain list of matches for specific cometition and season 
df_matches = sb.matches(competition_id=55, season_id=43)
# obtain event info for specific match
df_events = sb.events(match_id = 3788741)
df_events
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#      ball_receipt_outcome ball_recovery_offensive  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ...                   ...                     ...
# 3798                  NaN                     NaN
# ...

# %%
df_throwIn = df_events.loc[df_events['pass_type'] == 'Throw-in']
df_throwIn
# Out:
#      ball_receipt_outcome ball_recovery_offensive  \
# 8                     NaN                     NaN
# 15                    NaN                     NaN
# 16                    NaN                     NaN
# 22                    NaN                     NaN
# 25                    NaN                     NaN
# 38                    NaN                     NaN
# 44                    NaN                     NaN
# 47                    NaN                     NaN
# 75                    NaN                     NaN
# 103                   NaN                     NaN
# 112                   NaN                     NaN
# 128                   NaN                     NaN
# 191                   NaN                     NaN
# 197                   NaN                     NaN
# 215                   NaN                     NaN
# 243                   NaN                     NaN
# 253                   NaN                     NaN
# 264                   NaN                     NaN
# ...

# %%
df_from_throwIn = df_events.loc[df_events['play_pattern'] == 'From Throw In']
df_shot = df_from_throwIn.loc[df_from_throwIn['type'] == 'Shot']
df_shot
# Out:
#      ball_receipt_outcome ball_recovery_offensive  \
# 3603                  NaN                     NaN
# 3605                  NaN                     NaN
# 3607                  NaN                     NaN
# 3610                  NaN                     NaN
# 3611                  NaN                     NaN
# 3612                  NaN                     NaN
# 3613                  NaN                     NaN
# 3614                  NaN                     NaN
# 3620                  NaN                     NaN
# 3625                  NaN                     NaN
# 3626                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 3603                            NaN              NaN                NaN
# 3605                            NaN              NaN                NaN
# 3607                            NaN              NaN                NaN
# ...

# %%
# figure out which throw in is correlated to which shot

# %%
throw_shots = []
throw_shots_count = 0
for row in df_throwIn.index:
    if (df_throwIn["type"][row]=="Shot"):
        throw_shots.append("Success")
        throw_shots_count+=1
    else:
        throw_shots.append("Failure")

df_shot= df_throwIn.assign(throwIn_to_shot=throw_shots)
df_shot
# Out:
#      ball_receipt_outcome ball_recovery_offensive  \
# 8                     NaN                     NaN
# 9                     NaN                     NaN
# 10                    NaN                     NaN
# 11                    NaN                     NaN
# 12                    NaN                     NaN
# ...                   ...                     ...
# 3763                  NaN                     NaN
# 3769                  NaN                     NaN
# 3770                  NaN                     NaN
# 3772                  NaN                     NaN
# 3792                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 8                               NaN              NaN                NaN
# 9                               NaN              NaN                NaN
# 10                              NaN              NaN                NaN
# ...

# %%
df_shot.drop(df_shot.columns.difference(['throwIn_to_shot','location', "pass_height", "pass_angle", "pass_length"]), 1, inplace=True)
df_shot_sort = df_shot.reset_index()
df_shot_sort
# Out:
# /var/folders/n4/wr2pjk454g5cxqdbd2qywndc0000gn/T/ipykernel_63074/2048535862.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_shot.drop(df_shot.columns.difference(['throwIn_to_shot','location', "pass_height", "pass_angle", "pass_length"]), 1, inplace=True)
#       index       location  pass_angle  pass_height  pass_length  \
# 0         8    [43.1, 0.1]    2.876891     Low Pass    28.285154
# 1         9    [3.3, 12.7]    1.377496  Ground Pass    23.945980
# 2        10    [9.1, 38.9]    0.703946  Ground Pass    13.905395
# 3        11   [28.8, 49.9]   -1.458489  Ground Pass    26.768639
# 4        12   [37.9, 20.2]    1.740855  Ground Pass    20.089798
# ...     ...            ...         ...          ...          ...
# 1164   3763   [82.9, 74.4]         NaN          NaN          NaN
# 1165   3769   [95.7, 14.6]         NaN          NaN          NaN
# ...
